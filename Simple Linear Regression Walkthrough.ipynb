# %% [markdown]
# ## Simple Linear Regression Walkthough in Python

# %%
import pandas as pd
import numpy as np
import random

from matplotlib import pyplot as plt
import seaborn as sns
sns.set_palette(sns.color_palette("Spectral"))
sns.set_style("darkgrid")

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 1000
mpl.rcParams["axes.labelsize"] = 15

# %% [markdown]
# #### Generating Random Data

# %%
# Generate random data with noise fitting y = b_0 + b_1 * x 
random.seed(1234)
y = []
x = []
b_1 = 2
b_0 = 10
random_deviation_factor = 100

def get_random_deviation(deviation_size) -> float: 
    return random.uniform(-1 * deviation_size, deviation_size)

def get_random_val() -> float:
    return random.uniform(0,100)

for _ in range(50):
    x_ir = get_random_val()
    x.append(x_ir)
    y.append(b_0 + b_1 * (x_ir) + get_random_deviation(random_deviation_factor))

df = pd.DataFrame({"x":x,"y":y})

plot = df.plot.scatter('x','y', title = f"y = {b_1}*x + uniform(-{random_deviation_factor},{random_deviation_factor})")
plt.axhline(y=0, color='k', linestyle='-')
plt.axvline(x=0, color='k', linestyle='-')

plt.savefig("scatter.png")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# #### Plotting Candidate Regression Lines

# %%
# Randomly plot a bunch of candidate regression lines and record their MSE and parameters
x = np.array(x)
y_actual = b_1 + x * b_1

# generate parameter guesses
num_points = 100
b_1_g = np.random.uniform(-5,5,size = num_points)
b_0_g = np.random.uniform(-5,5,size = num_points)

# plot a few random lines form parameter guesses 
plt.clf()
df.plot.scatter('x','y', title = f"y = {b_1}*x + uniform(-{random_deviation_factor},{random_deviation_factor})")
plt.axhline(y=0, color='k', linestyle='-')
plt.axvline(x=0, color='k', linestyle='-')

x_lin = np.linspace(0,100,100)
for i in "bgrcmykw":
    random_point = random.randint(0,num_points-1)
    plt.plot(x_lin, x_lin * b_1_g[random_point] + b_0_g[random_point], 
             '-{}'.format(i), label='y={0:.2f}x+{0:.2f}'.format(b_1_g[random_point],b_0_g[random_point]))
plt.legend()
plt.savefig("scatter_lines.png")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# #### Visualize Loss Surface

# %%
# Visualize Loss Surface

# Use intervals instead of random points for smooth curve
x = range(1,101)
y = list(map(lambda b: b*2 + 1,x))
b_0, b_1 = np.meshgrid(np.linspace(-4,4,100), np.linspace(-4,4,100))  

# ypred[b_1][b_0]
ypred = b_1*x + b_0  
loss = np.power((y-ypred),2)/len(x)

fig = plt.figure()  
ax = fig.gca(projection='3d')  
surf = ax.plot_surface(b_1, b_0, loss, cmap='plasma', edgecolor='none')  
ax.set_xlabel('Slope')  
ax.set_ylabel('Bias')  
ax.set_zlabel("Loss: MSE")
ax.title.set_text('Loss Surface of y = 2x+1')

fig.savefig("loss_surface.png")
# Out:
# C:\Users\randymi\AppData\Local\Temp\ipykernel_3872\534764035.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
